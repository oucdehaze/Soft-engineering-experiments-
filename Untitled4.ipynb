# %%
! unzip "/content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master.zip" -d "/content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master"
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master.zip
#  extracting: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/.gitignore
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/LICENSE
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/README.md
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_10_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_1_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_2_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_3_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_4_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_5_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_6_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_7_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_8_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/NYU2_9_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data/Thumbs.db
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_10_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_1_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_2_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_3_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_4_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_5_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_6_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_7_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_4_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_8_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_1_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_1_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_1_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_4_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_4_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_5_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_5_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_5_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_6_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_6_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_6_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_7_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/NYU2_9_7_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/data_data/data/Thumbs.db
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_10.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_4.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_5.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_6.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_7.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_8.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images/NYU2_9.jpg
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_10.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_4.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_5.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_7.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_8.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data/images_data/data/NYU2_9.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/dataloader.py
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/dehaze.py
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/net.py
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/pytorch-AOD-net.ipynb
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/results/
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/samples/
#  extracting: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/samples/dummyText.txt
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/snapshot/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/snapshot/dehazer.pth
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/snapshots/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/snapshots/dehazer.pth
#    creating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/NYU2_102_7_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/NYU2_741_7_2.jpg
#  extracting: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/canyon.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/guogong.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/indoor.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/man.png
#  extracting: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test.png
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test10.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test11.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test12.jpg
#  extracting: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test13.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test14.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test15.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test17.bmp
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test4.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test5.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test6.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test7.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test8.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/test_images/test9.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/train.py
#   inflating: /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/try.ipynb

# %%
import os
print(os.getcwd())
os.chdir("/content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master")
print(os.getcwd())
# Out:
# /content
# /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master

# %%
# dataloader.py import
import os
import sys

import torch
import torch.utils.data as data

import numpy as np
from PIL import Image
import glob
import random
import cv2

# %%
# dataloader.py
random.seed(1143)


def populate_train_list(orig_images_path, hazy_images_path):


	train_list = []
	val_list = []

	image_list_haze = glob.glob(hazy_images_path + "*.jpg")

	tmp_dict = {}

	for image in image_list_haze:
		image = image.split("/")[-1]
		key = image.split("_")[0] + "_" + image.split("_")[1] + ".jpg"
		if key in tmp_dict.keys():
			tmp_dict[key].append(image)
		else:
			tmp_dict[key] = []
			tmp_dict[key].append(image)


	train_keys = []
	val_keys = []

	len_keys = len(tmp_dict.keys())
	for i in range(len_keys):
		if i < len_keys*9/10:
			train_keys.append(list(tmp_dict.keys())[i])
		else:
			val_keys.append(list(tmp_dict.keys())[i])


	for key in list(tmp_dict.keys()):

		if key in train_keys:
			for hazy_image in tmp_dict[key]:

				train_list.append([orig_images_path + key, hazy_images_path + hazy_image])


		else:
			for hazy_image in tmp_dict[key]:

				val_list.append([orig_images_path + key, hazy_images_path + hazy_image])



	random.shuffle(train_list)
	random.shuffle(val_list)

	return train_list, val_list



class dehazing_loader(data.Dataset):

	def __init__(self, orig_images_path, hazy_images_path, mode='train'):

		self.train_list, self.val_list = populate_train_list(orig_images_path, hazy_images_path)

		if mode == 'train':
			self.data_list = self.train_list
			print("Total training examples:", len(self.train_list))
		else:
			self.data_list = self.val_list
			print("Total validation examples:", len(self.val_list))



	def __getitem__(self, index):

		data_orig_path, data_hazy_path = self.data_list[index]

		data_orig = Image.open(data_orig_path)
		data_hazy = Image.open(data_hazy_path)

		data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
		data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)

		data_orig = (np.asarray(data_orig)/255.0)
		data_hazy = (np.asarray(data_hazy)/255.0)

		data_orig = torch.from_numpy(data_orig).float()
		data_hazy = torch.from_numpy(data_hazy).float()

		return data_orig.permute(2,0,1), data_hazy.permute(2,0,1)

	def __len__(self):
		return len(self.data_list)

# %%
# ! nvcc --version
# 使用GPU训练，可以在菜单 "代码执行工具" -> "更改运行时类型" 里进行设置
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(torch.__version__, torch.cuda.is_available())
# Out:
# 2.1.0+cu118 False

# %%
# net.py import
import torch
import torch.nn as nn
import math

# %%
# net.py
class dehaze_net(nn.Module):

	def __init__(self):
		super(dehaze_net, self).__init__()

		self.relu = nn.ReLU(inplace=True)

		self.e_conv1 = nn.Conv2d(3,3,1,1,0,bias=True)
		self.e_conv2 = nn.Conv2d(3,3,3,1,1,bias=True)
		self.e_conv3 = nn.Conv2d(6,3,5,1,2,bias=True)
		self.e_conv4 = nn.Conv2d(6,3,7,1,3,bias=True)
		self.e_conv5 = nn.Conv2d(12,3,3,1,1,bias=True)

	def forward(self, x):
		source = []
		source.append(x)

		x1 = self.relu(self.e_conv1(x))
		x2 = self.relu(self.e_conv2(x1))

		concat1 = torch.cat((x1,x2), 1)
		x3 = self.relu(self.e_conv3(concat1))

		concat2 = torch.cat((x2, x3), 1)
		x4 = self.relu(self.e_conv4(concat2))

		concat3 = torch.cat((x1,x2,x3,x4),1)
		x5 = self.relu(self.e_conv5(concat3))

		clean_image = self.relu((x5 * x) - x5 + 1)

		return clean_image

# %%
# train.py import
import torch
import torch.nn as nn
import torchvision
import torch.backends.cudnn as cudnn
import torch.optim
import os
import sys
import argparse
import time
import dataloader
import net
import numpy as np
from torchvision import transforms

# %%
# import os
print(os.getcwd())
os.chdir("/content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master
# /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/data

# %%
print(os.getcwd())
os.chdir("/content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master/")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master
# /content/drive/MyDrive/Colab Notebooks/PyTorch-Image-Dehazing-master

# %%
# train.py
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)


def train(config):

	dehaze_net = net.dehaze_net()
	dehaze_net.apply(weights_init)

	train_dataset = dehazing_loader(config.orig_images_path,
											 config.hazy_images_path)
	val_dataset = dehazing_loader(config.orig_images_path,
											 config.hazy_images_path, mode="val")
	train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=config.train_batch_size, shuffle=True, num_workers=config.num_workers, pin_memory=True)
	val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=config.val_batch_size, shuffle=True, num_workers=config.num_workers, pin_memory=True)

	criterion = nn.MSELoss()
	optimizer = torch.optim.Adam(dehaze_net.parameters(), lr=config.lr, weight_decay=config.weight_decay)

	dehaze_net.train()

	for epoch in range(config.num_epochs):
		for iteration, (img_orig, img_haze) in enumerate(train_loader):

			#img_orig = img_orig.cuda()
			#img_haze = img_haze.cuda()

			clean_image = dehaze_net(img_haze)

			loss = criterion(clean_image, img_orig)

			optimizer.zero_grad()
			loss.backward()
			torch.nn.utils.clip_grad_norm(dehaze_net.parameters(),config.grad_clip_norm)
			optimizer.step()

			if ((iteration+1) % config.display_iter) == 0:
				print("Loss at iteration", iteration+1, ":", loss.item())
			if ((iteration+1) % config.snapshot_iter) == 0:

				torch.save(dehaze_net.state_dict(), config.snapshots_folder + "Epoch" + str(epoch) + '.pth')

		# Validation Stage
		for iter_val, (img_orig, img_haze) in enumerate(val_loader):

			#img_orig = img_orig.cuda()
			#img_haze = img_haze.cuda()

			clean_image = dehaze_net(img_haze)

			torchvision.utils.save_image(torch.cat((img_haze, clean_image, img_orig),0), config.sample_output_folder+str(iter_val+1)+".jpg")

		torch.save(dehaze_net.state_dict(), config.snapshots_folder + "dehazer.pth")

if __name__ == "__main__":

	parser = argparse.ArgumentParser()

	# Input Parameters
	parser.add_argument('--orig_images_path', type=str, default="data/images/")
	parser.add_argument('--hazy_images_path', type=str, default="data/data/")
	parser.add_argument('--lr', type=float, default=0.0001)
	parser.add_argument('--weight_decay', type=float, default=0.0001)
	parser.add_argument('--grad_clip_norm', type=float, default=0.1)
	parser.add_argument('--num_epochs', type=int, default=10)
	parser.add_argument('--train_batch_size', type=int, default=8)
	parser.add_argument('--val_batch_size', type=int, default=8)
	parser.add_argument('--num_workers', type=int, default=4)
	parser.add_argument('--display_iter', type=int, default=10)
	parser.add_argument('--snapshot_iter', type=int, default=200)
	parser.add_argument('--snapshots_folder', type=str, default="snapshots/")
	parser.add_argument('--sample_output_folder', type=str, default="samples/")

	config = parser.parse_known_args()[0]

	if not os.path.exists(config.snapshots_folder):
		os.mkdir(config.snapshots_folder)
	if not os.path.exists(config.sample_output_folder):
		os.mkdir(config.sample_output_folder)

	train(config)
# Out:
# Total training examples: 171
# Total validation examples: 14
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-23-464f28c05a12>:40: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(dehaze_net.parameters(),config.grad_clip_norm)
# Loss at iteration 10 : 0.33288320899009705
# Loss at iteration 20 : 0.30301228165626526
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.3389490842819214
# Loss at iteration 20 : 0.29936233162879944
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.32288020849227905
# Loss at iteration 20 : 0.3163600564002991
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.3001548945903778
# Loss at iteration 20 : 0.3159705400466919
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.2971689999103546
# Loss at iteration 20 : 0.33916619420051575
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.28591188788414
# Loss at iteration 20 : 0.3070967197418213
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.3263571560382843
# Loss at iteration 20 : 0.31307488679885864
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.30393514037132263
# Loss at iteration 20 : 0.299814373254776
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.27869853377342224
# Loss at iteration 20 : 0.30523160099983215
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# Loss at iteration 10 : 0.30080634355545044
# Loss at iteration 20 : 0.2893977463245392
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:80: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_orig = data_orig.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)
# <ipython-input-6-582ba3bad29d>:81: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   data_hazy = data_hazy.resize((480,640), Image.ANTIALIAS)

# %%
# dehaze.py import
import torch
import torch.nn as nn
import torchvision
import torch.backends.cudnn as cudnn
import torch.optim
import os
import sys
import argparse
import time
import dataloader
import net
import numpy as np
from torchvision import transforms
from PIL import Image
import glob

# %%
# dahaze.py
def dehaze_image(image_path):

	data_hazy = Image.open(image_path)
	data_hazy = (np.asarray(data_hazy)/255.0)

	data_hazy = torch.from_numpy(data_hazy).float()
	data_hazy = data_hazy.permute(2,0,1)
	data_hazy = data_hazy.unsqueeze(0)

	dehaze_net = net.dehaze_net()
	dehaze_net.load_state_dict(torch.load('snapshots/dehazer.pth'))

	clean_image = dehaze_net(data_hazy)
	torchvision.utils.save_image(torch.cat((data_hazy, clean_image),0), "results/" + image_path.split("/")[-1])


if __name__ == '__main__':

	test_list = glob.glob("test_images/*")

	for image in test_list:

		dehaze_image(image)
		print(image, "done!")
# Out:
# test_images/test10.jpg done!
# test_images/test17.bmp done!
# test_images/test15.jpg done!
# test_images/test13.jpg done!
# test_images/test11.jpg done!
# test_images/NYU2_102_7_2.jpg done!
# test_images/test14.jpg done!
# test_images/test6.jpg done!
# test_images/test12.jpg done!
# test_images/test9.jpg done!
# test_images/test5.jpg done!
# test_images/test.png done!
# test_images/test3.jpg done!
# test_images/test8.jpg done!
# test_images/indoor.jpg done!
# test_images/test2.jpg done!
# test_images/test4.jpg done!
# test_images/man.png done!
# test_images/test7.jpg done!
# test_images/NYU2_741_7_2.jpg done!
# test_images/canyon.png done!
# test_images/guogong.png done!
